# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnasharma1902/Spyne_Assignment/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<AlteryxDocument yxmdVer="2024.1" RunE2="T">
  <Nodes>
    <Node ToolID="1">
      <GuiSettings Plugin="AlteryxBasePluginsGui.DbFileInput.DbFileInput">
        <Position x="66" y="126" />
      </GuiSettings>
      <Properties>
        <Configuration>
          <Passwords />
          <File />
          <FormatSpecificOptions UseDcm="true" Format="23" RecordLimit="">
            <Query>select *
from "ANALYTICS"."SCHEMA1"."CUSTOMER"</Query>
            <TableStyle>Quoted</TableStyle>
            <CacheData>False</CacheData>
            <Table />
            <SessionReadOnly>True</SessionReadOnly>
            <ReadUncommitted>False</ReadUncommitted>
            <Connection DcmType="ConnectionId">96615386-8bd8-474c-8f95-8471c9d4bdd0</Connection>
            <NoProgress>True</NoProgress>
            <PostSQL />
            <PreSQLOnConfig>True</PreSQLOnConfig>
            <PreSQL />
          </FormatSpecificOptions>
        </Configuration>
        <Annotation DisplayMode="0">
          <Name />
          <DefaultAnnotationText>dcm:Snowflake ODBC — Username and password
Query=select *
from "ANALYTICS"....</DefaultAnnotationText>
          <Left value="False" />
        </Annotation>
        <MetaInfo connection="Output">
          <RecordInfo>
            <Field name="C_CUSTKEY" scale="0" size="39" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_NAME" size="25" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_ADDRESS" size="40" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_NATIONKEY" scale="0" size="39" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_PHONE" size="15" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_ACCTBAL" scale="2" size="14" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_MKTSEGMENT" size="10" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_COMMENT" size="117" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
          </RecordInfo>
        </MetaInfo>
      </Properties>
      <EngineSettings EngineDll="AlteryxBasePluginsEngine.dll" EngineDllEntryPoint="AlteryxDbFileInput" />
    </Node>
    <Node ToolID="2">
      <GuiSettings Plugin="AlteryxBasePluginsGui.Filter.Filter">
        <Position x="222" y="198" />
      </GuiSettings>
      <Properties>
        <Configuration>
          <Expression>[C_ACCTBAL] &gt; 5000 AND [C_ACCTBAL] &lt; 9000</Expression>
          <Mode>Custom</Mode>
        </Configuration>
        <Annotation DisplayMode="0">
          <Name />
          <DefaultAnnotationText>[C_ACCTBAL] &gt; 5000 AND [C_ACCTBAL] &lt; 9000</DefaultAnnotationText>
          <Left value="False" />
        </Annotation>
        <MetaInfo connection="True">
          <RecordInfo>
            <Field name="C_CUSTKEY" scale="0" size="39" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_NAME" size="25" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_ADDRESS" size="40" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_NATIONKEY" scale="0" size="39" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_PHONE" size="15" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_ACCTBAL" scale="2" size="14" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_MKTSEGMENT" size="10" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_COMMENT" size="117" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
          </RecordInfo>
        </MetaInfo>
        <MetaInfo connection="False">
          <RecordInfo>
            <Field name="C_CUSTKEY" scale="0" size="39" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_NAME" size="25" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_ADDRESS" size="40" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_NATIONKEY" scale="0" size="39" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_PHONE" size="15" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_ACCTBAL" scale="2" size="14" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_MKTSEGMENT" size="10" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_COMMENT" size="117" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
          </RecordInfo>
        </MetaInfo>
      </Properties>
      <EngineSettings EngineDll="AlteryxBasePluginsEngine.dll" EngineDllEntryPoint="AlteryxFilter" />
    </Node>
    <Node ToolID="3">
      <GuiSettings Plugin="AlteryxSpatialPluginsGui.Summarize.Summarize">
        <Position x="354" y="186" />
      </GuiSettings>
      <Properties>
        <Configuration>
          <SummarizeFields>
            <SummarizeField field="C_NATIONKEY" action="GroupBy" rename="C_NATIONKEY" />
            <SummarizeField field="C_MKTSEGMENT" action="First" rename="First_C_MKTSEGMENT" />
          </SummarizeFields>
        </Configuration>
        <Annotation DisplayMode="0">
          <Name />
          <DefaultAnnotationText />
          <Left value="False" />
        </Annotation>
        <MetaInfo connection="Output">
          <RecordInfo>
            <Field name="C_NATIONKEY" scale="0" size="39" source="Summarize: GroupBy - C_NATIONKEY" type="FixedDecimal" />
            <Field name="First_C_MKTSEGMENT" size="10" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
          </RecordInfo>
        </MetaInfo>
      </Properties>
      <EngineSettings EngineDll="AlteryxSpatialPluginsEngine.dll" EngineDllEntryPoint="AlteryxSummarize" />
    </Node>
    <Node ToolID="4">
      <GuiSettings Plugin="AlteryxBasePluginsGui.Filter.Filter">
        <Position x="222" y="42" />
      </GuiSettings>
      <Properties>
        <Configuration>
          <Expression>[C_MKTSEGMENT] = "AUTOMOBILE"</Expression>
          <Mode>Custom</Mode>
        </Configuration>
        <Annotation DisplayMode="0">
          <Name />
          <DefaultAnnotationText>[C_MKTSEGMENT] = "AUTOMOBILE"</DefaultAnnotationText>
          <Left value="False" />
        </Annotation>
        <MetaInfo connection="True">
          <RecordInfo>
            <Field name="C_CUSTKEY" scale="0" size="39" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_NAME" size="25" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_ADDRESS" size="40" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_NATIONKEY" scale="0" size="39" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_PHONE" size="15" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_ACCTBAL" scale="2" size="14" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_MKTSEGMENT" size="10" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_COMMENT" size="117" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
          </RecordInfo>
        </MetaInfo>
        <MetaInfo connection="False">
          <RecordInfo>
            <Field name="C_CUSTKEY" scale="0" size="39" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_NAME" size="25" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_ADDRESS" size="40" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_NATIONKEY" scale="0" size="39" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_PHONE" size="15" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_ACCTBAL" scale="2" size="14" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="FixedDecimal" />
            <Field name="C_MKTSEGMENT" size="10" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
            <Field name="C_COMMENT" size="117" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
          </RecordInfo>
        </MetaInfo>
      </Properties>
      <EngineSettings EngineDll="AlteryxBasePluginsEngine.dll" EngineDllEntryPoint="AlteryxFilter" />
    </Node>
    <Node ToolID="5">
      <GuiSettings Plugin="AlteryxSpatialPluginsGui.Summarize.Summarize">
        <Position x="354" y="30" />
      </GuiSettings>
      <Properties>
        <Configuration>
          <SummarizeFields>
            <SummarizeField field="C_ACCTBAL" action="Sum" rename="Sum_C_ACCTBAL_SEG" />
            <SummarizeField field="C_NATIONKEY" action="GroupBy" rename="C_NATIONKEY" />
          </SummarizeFields>
        </Configuration>
        <Annotation DisplayMode="0">
          <Name />
          <DefaultAnnotationText />
          <Left value="False" />
        </Annotation>
        <MetaInfo connection="Output">
          <RecordInfo>
            <Field name="Sum_C_ACCTBAL_SEG" scale="2" size="14" source="Summarize: Sum - C_ACCTBAL" type="FixedDecimal" />
            <Field name="C_NATIONKEY" scale="0" size="39" source="Summarize: GroupBy - C_NATIONKEY" type="FixedDecimal" />
          </RecordInfo>
        </MetaInfo>
      </Properties>
      <EngineSettings EngineDll="AlteryxSpatialPluginsEngine.dll" EngineDllEntryPoint="AlteryxSummarize" />
    </Node>
    <Node ToolID="7">
      <GuiSettings Plugin="AlteryxBasePluginsGui.BrowseV2.BrowseV2">
        <Position x="606" y="114" />
      </GuiSettings>
      <Properties>
        <Configuration>
          <TempFile>C:\Users\aasth\AppData\Local\Temp\Alteryx\Engine_2520_79a40f54cdb6490ca3f16077db05a0bc_\Engine_2520_fc0f5fe4faabc2458418d9b4dbcc98fd~.yxdb</TempFile>
          <TempFileDataProfiling />
          <Layout>
            <ViewMode>Single</ViewMode>
            <ViewSize value="100" />
            <View1>
              <DefaultTab>Profile</DefaultTab>
              <Hints>
                <Table />
              </Hints>
            </View1>
            <View2 />
          </Layout>
        </Configuration>
        <Annotation DisplayMode="0">
          <Name />
          <DefaultAnnotationText />
          <Left value="False" />
        </Annotation>
      </Properties>
      <EngineSettings EngineDll="AlteryxBasePluginsEngine.dll" EngineDllEntryPoint="AlteryxBrowseV2" />
    </Node>
    <Node ToolID="8">
      <GuiSettings Plugin="AlteryxBasePluginsGui.Join.Join">
        <Position x="486" y="114" />
      </GuiSettings>
      <Properties>
        <Configuration joinByRecordPos="False">
          <JoinInfo connection="Left">
            <Field field="C_NATIONKEY" />
          </JoinInfo>
          <JoinInfo connection="Right">
            <Field field="C_NATIONKEY" />
          </JoinInfo>
          <SelectConfiguration>
            <Configuration outputConnection="Join">
              <OrderChanged value="False" />
              <CommaDecimal value="False" />
              <SelectFields>
                <SelectField field="Right_C_NATIONKEY" selected="False" rename="Right_C_NATIONKEY" input="Right_" />
                <SelectField field="*Unknown" selected="True" />
              </SelectFields>
            </Configuration>
          </SelectConfiguration>
        </Configuration>
        <Annotation DisplayMode="0">
          <Name />
          <DefaultAnnotationText />
          <Left value="False" />
        </Annotation>
        <MetaInfo connection="Left">
          <RecordInfo>
            <Field name="Sum_C_ACCTBAL_SEG" scale="2" size="14" source="Summarize: Sum - C_ACCTBAL" type="FixedDecimal" />
            <Field name="C_NATIONKEY" scale="0" size="39" source="Summarize: GroupBy - C_NATIONKEY" type="FixedDecimal" />
          </RecordInfo>
        </MetaInfo>
        <MetaInfo connection="Join">
          <RecordInfo>
            <Field name="Sum_C_ACCTBAL_SEG" scale="2" size="14" source="Summarize: Sum - C_ACCTBAL" type="FixedDecimal" />
            <Field name="C_NATIONKEY" scale="0" size="39" source="Summarize: GroupBy - C_NATIONKEY" type="FixedDecimal" />
            <Field name="First_C_MKTSEGMENT" size="10" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
          </RecordInfo>
        </MetaInfo>
        <MetaInfo connection="Right">
          <RecordInfo>
            <Field name="C_NATIONKEY" scale="0" size="39" source="Summarize: GroupBy - C_NATIONKEY" type="FixedDecimal" />
            <Field name="First_C_MKTSEGMENT" size="10" source="File: select * &#xA;from &quot;ANALYTICS&quot;.&quot;SCHEMA1&quot;.&quot;CUSTOMER&quot;" type="V_WString" />
          </RecordInfo>
        </MetaInfo>
      </Properties>
      <EngineSettings EngineDll="AlteryxBasePluginsEngine.dll" EngineDllEntryPoint="AlteryxJoin" />
    </Node>
  </Nodes>
  <Connections>
    <Connection>
      <Origin ToolID="1" Connection="Output" />
      <Destination ToolID="2" Connection="Input" />
    </Connection>
    <Connection>
      <Origin ToolID="1" Connection="Output" />
      <Destination ToolID="4" Connection="Input" />
    </Connection>
    <Connection>
      <Origin ToolID="2" Connection="True" />
      <Destination ToolID="3" Connection="Input" />
    </Connection>
    <Connection>
      <Origin ToolID="3" Connection="Output" />
      <Destination ToolID="8" Connection="Right" />
    </Connection>
    <Connection>
      <Origin ToolID="5" Connection="Output" />
      <Destination ToolID="8" Connection="Left" />
    </Connection>
    <Connection>
      <Origin ToolID="4" Connection="True" />
      <Destination ToolID="5" Connection="Input" />
    </Connection>
    <Connection>
      <Origin ToolID="8" Connection="Join" />
      <Destination ToolID="7" Connection="Input" />
    </Connection>
  </Connections>
  <Properties>
    <Memory default="True" />
    <GlobalRecordLimit value="0" />
    <TempFiles default="True" />
    <Annotation on="True" includeToolName="False" />
    <ConvErrorLimit value="10" />
    <ConvErrorLimit_Stop value="False" />
    <CancelOnError value="False" />
    <DisableBrowse value="False" />
    <EnablePerformanceProfiling value="False" />
    <RunWithE2 value="True" />
    <PredictiveToolsCodePage value="1252" />
    <DisableAllOutput value="False" />
    <ShowAllMacroMessages value="False" />
    <ShowConnectionStatusIsOn value="True" />
    <ShowConnectionStatusOnlyWhenRunning value="True" />
    <ZoomLevel value="0" />
    <LayoutType>Horizontal</LayoutType>
    <IsTemplate value="False" />
    <MetaInfo>
      <NameIsFileName value="True" />
      <Name />
      <Description />
      <RootToolName />
      <ToolVersion />
      <ToolInDb value="False" />
      <CategoryName />
      <SearchTags />
      <Author />
      <Company />
      <Copyright />
      <DescriptionLink actual="" displayed="" />
      <Example>
        <Description />
        <File />
      </Example>
      <WorkflowId value="f10e78e8-14bd-4406-a394-6e6cdc456091" />
      <Telemetry>
        <PreviousWorkflowId value="" />
        <OriginWorkflowId value="f10e78e8-14bd-4406-a394-6e6cdc456091" />
      </Telemetry>
      <PlatformWorkflowId value="" />
    </MetaInfo>
    <Events>
      <Enabled value="True" />
    </Events>
  </Properties>
</AlteryxDocument>
